# %% [markdown]
# Answers for Week 2
#
# * Name: Sophie Leszek
# * Username: zeleszek
# * Student s-number: s5686709
# * Group (AS1, etc.): AS5

# %% [markdown]
# #2.5
#
# $$\boxed{\displaystyle\sum_{k = 0}^{\infty} \frac{1}{4k^2 - 1} = \frac{1}{2}} \space \boxed{\int_0^\pi \mathrm{e}^{ix}\, \mathrm{d}x = 2i}$$

# %%
#2.12

from IPython.display import display, Math
from math import atan2, degrees, pi

a = input("x =")
b = input("y =")

x = eval(a)
y = eval(b)

c = atan2(y, x)
d = rf"\phi = {c}"
m = Math(d)
display(m)

if 0 < c < pi/2 :
    print(f"the angle is in the first quarter")
elif pi > c > pi/2 :
    print(f"the angle is in the second quarter")
elif 3*pi/2 > c > pi :
    print(f"the angle is in the third quarter")
elif 2*pi > c > 3*pi/2 :
    print(f"the angle is in the fourth quarter")
elif 0 > c > -pi/2 :
    print(f"the angle is in the fourth quarter")
elif -pi < c < -pi/2 :
    print(f"the angle is in the third quarter")
elif -3*pi/2 < c < -pi :
    print(f"the angle is in the second quarter")
elif -2*pi < c < -3*pi/2 :
    print(f"the angle is in the first quarter")
# Out:
# x = 1
# y = 4
# $\displaystyle \phi = 1.3258176636680326$
# the angle is in the first quarter

# %% [markdown]
# - the difference is that atan2() knows the diference between the signs of both inputs, and therefore the output is in the correct quadrant. atan() does not distinguish the results like that

# %%
#14
import math
n = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]

n.append(0.51)
n.remove(2.12)
print(f"value at index 6:", n[6])
print(f"1.46 is at index", n.index(1.46))

s = slice(2, 8, 2)
print(f"sliced:", n[s])
print(f"the sum:", sum(n[s]))
# Out:
# value at index 6: 1.97
# 1.46 is at index 1
# sliced: [1.41, 0.98, 1.97]
# the sum: 4.359999999999999

# %%
#2.15

night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

n1 = set(night1)
n2 = set(night2)
print(f"set of values from night1:", n1)
print(f"set of values from night2:", n2)

int = set.intersection(n1, n2)
n = list(int)
print(f"The intersection of the sets is:", n)
print(f" 5 is in the intersection:", 5 in n)
print(f" 5 is in night1:", 5 in n1)
# Out:
# set of values from night1: {0, 1, 2, 3, 4, 5, 7, 9}
# set of values from night2: {0, 1, 2, 3, 4}
# The intersection of the sets is: [0, 1, 2, 3, 4]
#  5 is in the intersection: False
#  5 is in night1: True

# %%
#2.19
import numpy as np

random_numbers = np.random.normal(loc=0.0, scale=1.4, size=100000)
std = np.std(random_numbers)
print(std)
# Out:
# 1.4016070533238785

# %%
#2.21

n1 = 1
n2 = 2

for i in range (3, 101):
    n = n1 + n2
    n1 = n2
    n2 = n

print(n2)
# Out:
# 573147844013817084101

# %% [markdown]
# #2.23
#
# ![Screenshot 2026-02-21 at 15.33.46.png](attachment:9e77fe3e-9150-4906-9666-662b26994150.png)

# %%
#2.25

# %%
#2.26
